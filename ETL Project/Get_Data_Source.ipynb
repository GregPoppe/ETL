# %%
# Dependencies
import numpy as np
import pandas as pd
import config
import matplotlib.pyplot as plt
import requests
import time
from datetime import date, datetime, timedelta
import json
import dateutil
from time import mktime
from pandas.io.json import json_normalize
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# OANDA API Key

api_key =  config.oanda_api

# %%
#Initialize MySQL Connection

rds_connection_string = "root:ggZtOs8585@127.0.0.1/raw_data_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
#set paramaters of data

#Price: A = Ask, B = Bid, M = Midpoint
price = 'A'

#Offset hours: In Hours. Set to 48 for now
offset = 200

#Granularity: S/M/H/D and time interval. Example M5 = 5 minutes
gran = 'M5'

#Pair
pair = 'EUR_USD'

# %%
#Get Dates for previous day
end_date = int(time.time()) 
start_date = end_date - 3600*offset

# %%
headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
}

params = {
    'price': price,
    'from': start_date,
    'to' : end_date,   
    'granularity': gran,
}

response = requests.get(f'https://api-fxpractice.oanda.com/v3/instruments/{pair}/candles', headers=headers, params=params).json()

# %%
response
# Out:
# {'instrument': 'EUR_USD',
#  'granularity': 'M5',
#  'candles': [{'complete': True,
#    'volume': 54,
#    'time': '2019-01-30T16:40:00.000000000Z',
#    'ask': {'o': '1.14219', 'h': '1.14228', 'l': '1.14202', 'c': '1.14226'}},
#   {'complete': True,
#    'volume': 70,
#    'time': '2019-01-30T16:45:00.000000000Z',
#    'ask': {'o': '1.14224', 'h': '1.14224', 'l': '1.14193', 'c': '1.14196'}},
#   {'complete': True,
#    'volume': 85,
#    'time': '2019-01-30T16:50:00.000000000Z',
#    'ask': {'o': '1.14194', 'h': '1.14194', 'l': '1.14160', 'c': '1.14175'}},
#   {'complete': True,
#    'volume': 77,
#    'time': '2019-01-30T16:55:00.000000000Z',
#    'ask': {'o': '1.14178', 'h': '1.14188', 'l': '1.14163', 'c': '1.14181'}},
#   {'complete': True,
#    'volume': 110,
#    'time': '2019-01-30T17:00:00.000000000Z',
#    'ask': {'o': '1.14183', 'h': '1.14194', 'l': '1.14140', 'c': '1.14141'}},
#   {'complete': True,
#    'volume': 78,
#    'time': '2019-01-30T17:05:00.000000000Z',
#    'ask': {'o': '1.14143', 'h': '1.14199', 'l': '1.14143', 'c': '1.14195'}},
#   {'complete': True,
#    'volume': 63,
#    'time': '2019-01-30T17:10:00.000000000Z',
#    'ask': {'o': '1.14198', 'h': '1.14209', 'l': '1.14183', 'c': '1.14187'}},
#   {'complete': True,
#    'volume': 54,
#    'time': '2019-01-30T17:15:00.000000000Z',
#    'ask': {'o': '1.14190', 'h': '1.14190', 'l': '1.14164', 'c': '1.14168'}},
#   {'complete': True,
#    'volume': 54,
#    'time': '2019-01-30T17:20:00.000000000Z',
#    'ask': {'o': '1.14165', 'h': '1.14183', 'l': '1.14160', 'c': '1.14166'}},
#   {'complete': True,
#    'volume': 54,
#    'time': '2019-01-30T17:25:00.000000000Z',
#    'ask': {'o': '1.14168', 'h': '1.14204', 'l': '1.14168', 'c': '1.14196'}},
#   {'complete': True,
#    'volume': 29,
#    'time': '2019-01-30T17:30:00.000000000Z',
#    'ask': {'o': '1.14199', 'h': '1.14210', 'l': '1.14197', 'c': '1.14201'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2019-01-30T17:35:00.000000000Z',
#    'ask': {'o': '1.14204', 'h': '1.14219', 'l': '1.14204', 'c': '1.14210'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2019-01-30T17:40:00.000000000Z',
#    'ask': {'o': '1.14207', 'h': '1.14232', 'l': '1.14203', 'c': '1.14227'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2019-01-30T17:45:00.000000000Z',
#    'ask': {'o': '1.14229', 'h': '1.14240', 'l': '1.14224', 'c': '1.14226'}},
#   {'complete': True,
#    'volume': 23,
#    'time': '2019-01-30T17:50:00.000000000Z',
#    'ask': {'o': '1.14229', 'h': '1.14232', 'l': '1.14215', 'c': '1.14217'}},
#   {'complete': True,
#    'volume': 49,
#    'time': '2019-01-30T17:55:00.000000000Z',
#    'ask': {'o': '1.14220', 'h': '1.14223', 'l': '1.14190', 'c': '1.14198'}},
#   {'complete': True,
#    'volume': 71,
#    'time': '2019-01-30T18:00:00.000000000Z',
#    'ask': {'o': '1.14196', 'h': '1.14197', 'l': '1.14163', 'c': '1.14182'}},
#   {'complete': True,
#    'volume': 29,
#    'time': '2019-01-30T18:05:00.000000000Z',
#    'ask': {'o': '1.14185', 'h': '1.14206', 'l': '1.14185', 'c': '1.14206'}},
#   {'complete': True,
#    'volume': 62,
#    'time': '2019-01-30T18:10:00.000000000Z',
#    'ask': {'o': '1.14204', 'h': '1.14214', 'l': '1.14185', 'c': '1.14193'}},
#   {'complete': True,
#    'volume': 76,
#    'time': '2019-01-30T18:15:00.000000000Z',
#    'ask': {'o': '1.14194', 'h': '1.14226', 'l': '1.14183', 'c': '1.14204'}},
#   {'complete': True,
#    'volume': 57,
#    'time': '2019-01-30T18:20:00.000000000Z',
#    'ask': {'o': '1.14206', 'h': '1.14237', 'l': '1.14206', 'c': '1.14235'}},
#   {'complete': True,
#    'volume': 66,
#    'time': '2019-01-30T18:25:00.000000000Z',
#    'ask': {'o': '1.14233', 'h': '1.14251', 'l': '1.14224', 'c': '1.14246'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2019-01-30T18:30:00.000000000Z',
#    'ask': {'o': '1.14249', 'h': '1.14255', 'l': '1.14244', 'c': '1.14251'}},
#   {'complete': True,
#    'volume': 65,
#    'time': '2019-01-30T18:35:00.000000000Z',
#    'ask': {'o': '1.14248', 'h': '1.14248', 'l': '1.14215', 'c': '1.14225'}},
#   {'complete': True,
#    'volume': 79,
#    'time': '2019-01-30T18:40:00.000000000Z',
#    'ask': {'o': '1.14227', 'h': '1.14236', 'l': '1.14200', 'c': '1.14200'}},
#   {'complete': True,
#    'volume': 55,
#    'time': '2019-01-30T18:45:00.000000000Z',
#    'ask': {'o': '1.14197', 'h': '1.14202', 'l': '1.14182', 'c': '1.14185'}},
#   {'complete': True,
#    'volume': 91,
#    'time': '2019-01-30T18:50:00.000000000Z',
#    'ask': {'o': '1.14188', 'h': '1.14199', 'l': '1.14157', 'c': '1.14169'}},
#   {'complete': True,
#    'volume': 127,
#    'time': '2019-01-30T18:55:00.000000000Z',
#    'ask': {'o': '1.14171', 'h': '1.14251', 'l': '1.14146', 'c': '1.14217'}},
#   {'complete': True,
#    'volume': 2231,
#    'time': '2019-01-30T19:00:00.000000000Z',
#    'ask': {'o': '1.14232', 'h': '1.14719', 'l': '1.14232', 'c': '1.14686'}},
#   {'complete': True,
#    'volume': 660,
#    'time': '2019-01-30T19:05:00.000000000Z',
#    'ask': {'o': '1.14688', 'h': '1.14721', 'l': '1.14615', 'c': '1.14621'}},
#   {'complete': True,
#    'volume': 646,
#    'time': '2019-01-30T19:10:00.000000000Z',
#    'ask': {'o': '1.14625', 'h': '1.14746', 'l': '1.14625', 'c': '1.14703'}},
#   {'complete': True,
#    'volume': 554,
#    'time': '2019-01-30T19:15:00.000000000Z',
#    'ask': {'o': '1.14705', 'h': '1.14771', 'l': '1.14699', 'c': '1.14767'}},
#   {'complete': True,
#    'volume': 358,
#    'time': '2019-01-30T19:20:00.000000000Z',
#    'ask': {'o': '1.14766', 'h': '1.14808', 'l': '1.14734', 'c': '1.14772'}},
#   {'complete': True,
#    'volume': 251,
#    'time': '2019-01-30T19:25:00.000000000Z',
#    'ask': {'o': '1.14776', 'h': '1.14797', 'l': '1.14705', 'c': '1.14715'}},
#   {'complete': True,
#    'volume': 416,
#    'time': '2019-01-30T19:30:00.000000000Z',
#    'ask': {'o': '1.14718', 'h': '1.14864', 'l': '1.14718', 'c': '1.14847'}},
#   {'complete': True,
#    'volume': 495,
#    'time': '2019-01-30T19:35:00.000000000Z',
#    'ask': {'o': '1.14851', 'h': '1.14948', 'l': '1.14851', 'c': '1.14934'}},
#   {'complete': True,
#    'volume': 363,
#    'time': '2019-01-30T19:40:00.000000000Z',
#    'ask': {'o': '1.14931', 'h': '1.15000', 'l': '1.14902', 'c': '1.14998'}},
#   {'complete': True,
#    'volume': 389,
#    'time': '2019-01-30T19:45:00.000000000Z',
#    'ask': {'o': '1.15001', 'h': '1.15026', 'l': '1.14935', 'c': '1.14937'}},
#   {'complete': True,
#    'volume': 494,
#    'time': '2019-01-30T19:50:00.000000000Z',
#    'ask': {'o': '1.14940', 'h': '1.14956', 'l': '1.14822', 'c': '1.14888'}},
#   {'complete': True,
#    'volume': 383,
#    'time': '2019-01-30T19:55:00.000000000Z',
#    'ask': {'o': '1.14890', 'h': '1.14942', 'l': '1.14835', 'c': '1.14930'}},
#   {'complete': True,
#    'volume': 408,
#    'time': '2019-01-30T20:00:00.000000000Z',
#    'ask': {'o': '1.14932', 'h': '1.14952', 'l': '1.14873', 'c': '1.14886'}},
#   {'complete': True,
#    'volume': 319,
#    'time': '2019-01-30T20:05:00.000000000Z',
#    'ask': {'o': '1.14888', 'h': '1.14914', 'l': '1.14849', 'c': '1.14851'}},
#   {'complete': True,
#    'volume': 381,
#    'time': '2019-01-30T20:10:00.000000000Z',
#    'ask': {'o': '1.14854', 'h': '1.14854', 'l': '1.14781', 'c': '1.14807'}},
#   {'complete': True,
#    'volume': 172,
#    'time': '2019-01-30T20:15:00.000000000Z',
#    'ask': {'o': '1.14805', 'h': '1.14864', 'l': '1.14797', 'c': '1.14820'}},
#   {'complete': True,
#    'volume': 136,
#    'time': '2019-01-30T20:20:00.000000000Z',
#    'ask': {'o': '1.14822', 'h': '1.14863', 'l': '1.14810', 'c': '1.14863'}},
#   {'complete': True,
#    'volume': 144,
#    'time': '2019-01-30T20:25:00.000000000Z',
#    'ask': {'o': '1.14861', 'h': '1.14870', 'l': '1.14836', 'c': '1.14854'}},
#   {'complete': True,
#    'volume': 103,
#    'time': '2019-01-30T20:30:00.000000000Z',
#    'ask': {'o': '1.14851', 'h': '1.14867', 'l': '1.14837', 'c': '1.14841'}},
#   {'complete': True,
#    'volume': 147,
#    'time': '2019-01-30T20:35:00.000000000Z',
#    'ask': {'o': '1.14838', 'h': '1.14871', 'l': '1.14828', 'c': '1.14867'}},
#   {'complete': True,
#    'volume': 136,
#    'time': '2019-01-30T20:40:00.000000000Z',
#    'ask': {'o': '1.14865', 'h': '1.14893', 'l': '1.14844', 'c': '1.14847'}},
#   {'complete': True,
#    'volume': 117,
#    'time': '2019-01-30T20:45:00.000000000Z',
#    'ask': {'o': '1.14845', 'h': '1.14847', 'l': '1.14805', 'c': '1.14830'}},
#   {'complete': True,
#    'volume': 131,
#    'time': '2019-01-30T20:50:00.000000000Z',
#    'ask': {'o': '1.14828', 'h': '1.14829', 'l': '1.14772', 'c': '1.14778'}},
#   {'complete': True,
#    'volume': 109,
#    'time': '2019-01-30T20:55:00.000000000Z',
#    'ask': {'o': '1.14777', 'h': '1.14822', 'l': '1.14771', 'c': '1.14814'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2019-01-30T21:00:00.000000000Z',
#    'ask': {'o': '1.14811', 'h': '1.14811', 'l': '1.14780', 'c': '1.14795'}},
#   {'complete': True,
#    'volume': 59,
#    'time': '2019-01-30T21:05:00.000000000Z',
#    'ask': {'o': '1.14792', 'h': '1.14792', 'l': '1.14765', 'c': '1.14778'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2019-01-30T21:10:00.000000000Z',
#    'ask': {'o': '1.14780', 'h': '1.14787', 'l': '1.14772', 'c': '1.14784'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2019-01-30T21:15:00.000000000Z',
#    'ask': {'o': '1.14786', 'h': '1.14789', 'l': '1.14766', 'c': '1.14782'}},
#   {'complete': True,
#    'volume': 42,
#    'time': '2019-01-30T21:20:00.000000000Z',
#    'ask': {'o': '1.14783', 'h': '1.14828', 'l': '1.14783', 'c': '1.14827'}},
#   {'complete': True,
#    'volume': 37,
#    'time': '2019-01-30T21:25:00.000000000Z',
#    'ask': {'o': '1.14829', 'h': '1.14838', 'l': '1.14811', 'c': '1.14819'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2019-01-30T21:30:00.000000000Z',
#    'ask': {'o': '1.14818', 'h': '1.14818', 'l': '1.14781', 'c': '1.14791'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2019-01-30T21:35:00.000000000Z',
#    'ask': {'o': '1.14788', 'h': '1.14790', 'l': '1.14775', 'c': '1.14782'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2019-01-30T21:40:00.000000000Z',
#    'ask': {'o': '1.14785', 'h': '1.14802', 'l': '1.14785', 'c': '1.14802'}},
#   {'complete': True,
#    'volume': 61,
#    'time': '2019-01-30T21:45:00.000000000Z',
#    'ask': {'o': '1.14800', 'h': '1.14832', 'l': '1.14792', 'c': '1.14822'}},
#   {'complete': True,
#    'volume': 51,
#    'time': '2019-01-30T21:50:00.000000000Z',
#    'ask': {'o': '1.14818', 'h': '1.14819', 'l': '1.14791', 'c': '1.14808'}},
#   {'complete': True,
#    'volume': 24,
#    'time': '2019-01-30T21:55:00.000000000Z',
#    'ask': {'o': '1.14807', 'h': '1.14813', 'l': '1.14801', 'c': '1.14811'}},
#   {'complete': True,
#    'volume': 34,
#    'time': '2019-01-30T22:00:00.000000000Z',
#    'ask': {'o': '1.14811', 'h': '1.14826', 'l': '1.14800', 'c': '1.14809'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2019-01-30T22:05:00.000000000Z',
#    'ask': {'o': '1.14813', 'h': '1.14816', 'l': '1.14810', 'c': '1.14815'}},
#   {'complete': True,
#    'volume': 53,
#    'time': '2019-01-30T22:10:00.000000000Z',
#    'ask': {'o': '1.14815', 'h': '1.14917', 'l': '1.14814', 'c': '1.14886'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2019-01-30T22:15:00.000000000Z',
#    'ask': {'o': '1.14886', 'h': '1.14886', 'l': '1.14858', 'c': '1.14871'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2019-01-30T22:20:00.000000000Z',
#    'ask': {'o': '1.14869', 'h': '1.14876', 'l': '1.14857', 'c': '1.14868'}},
#   {'complete': True,
#    'volume': 37,
#    'time': '2019-01-30T22:25:00.000000000Z',
#    'ask': {'o': '1.14867', 'h': '1.14884', 'l': '1.14866', 'c': '1.14871'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2019-01-30T22:30:00.000000000Z',
#    'ask': {'o': '1.14872', 'h': '1.14872', 'l': '1.14854', 'c': '1.14858'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2019-01-30T22:35:00.000000000Z',
#    'ask': {'o': '1.14856', 'h': '1.14859', 'l': '1.14856', 'c': '1.14857'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2019-01-30T22:40:00.000000000Z',
#    'ask': {'o': '1.14855', 'h': '1.14855', 'l': '1.14838', 'c': '1.14841'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2019-01-30T22:45:00.000000000Z',
#    'ask': {'o': '1.14837', 'h': '1.14844', 'l': '1.14823', 'c': '1.14829'}},
#   {'complete': True,
#    'volume': 7,
#    'time': '2019-01-30T22:50:00.000000000Z',
#    'ask': {'o': '1.14826', 'h': '1.14837', 'l': '1.14826', 'c': '1.14836'}},
#   {'complete': True,
#    'volume': 3,
#    'time': '2019-01-30T22:55:00.000000000Z',
#    'ask': {'o': '1.14837', 'h': '1.14837', 'l': '1.14828', 'c': '1.14828'}},
#   {'complete': True,
#    'volume': 35,
#    'time': '2019-01-30T23:00:00.000000000Z',
#    'ask': {'o': '1.14835', 'h': '1.14852', 'l': '1.14825', 'c': '1.14852'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-01-30T23:05:00.000000000Z',
#    'ask': {'o': '1.14853', 'h': '1.14854', 'l': '1.14849', 'c': '1.14851'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2019-01-30T23:10:00.000000000Z',
#    'ask': {'o': '1.14849', 'h': '1.14860', 'l': '1.14849', 'c': '1.14859'}},
#   {'complete': True,
#    'volume': 32,
#    'time': '2019-01-30T23:15:00.000000000Z',
#    'ask': {'o': '1.14862', 'h': '1.14874', 'l': '1.14852', 'c': '1.14863'}},
#   {'complete': True,
#    'volume': 20,
#    'time': '2019-01-30T23:20:00.000000000Z',
#    'ask': {'o': '1.14866', 'h': '1.14875', 'l': '1.14860', 'c': '1.14873'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-01-30T23:25:00.000000000Z',
#    'ask': {'o': '1.14870', 'h': '1.14872', 'l': '1.14866', 'c': '1.14868'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2019-01-30T23:30:00.000000000Z',
#    'ask': {'o': '1.14871', 'h': '1.14877', 'l': '1.14871', 'c': '1.14872'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2019-01-30T23:35:00.000000000Z',
#    'ask': {'o': '1.14874', 'h': '1.14897', 'l': '1.14874', 'c': '1.14897'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2019-01-30T23:40:00.000000000Z',
#    'ask': {'o': '1.14898', 'h': '1.14905', 'l': '1.14888', 'c': '1.14888'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2019-01-30T23:45:00.000000000Z',
#    'ask': {'o': '1.14890', 'h': '1.14896', 'l': '1.14882', 'c': '1.14888'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2019-01-30T23:50:00.000000000Z',
#    'ask': {'o': '1.14886', 'h': '1.14892', 'l': '1.14856', 'c': '1.14856'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2019-01-30T23:55:00.000000000Z',
#    'ask': {'o': '1.14853', 'h': '1.14863', 'l': '1.14843', 'c': '1.14863'}},
#   {'complete': True,
#    'volume': 94,
#    'time': '2019-01-31T00:00:00.000000000Z',
#    'ask': {'o': '1.14860', 'h': '1.14912', 'l': '1.14851', 'c': '1.14906'}},
#   {'complete': True,
#    'volume': 70,
#    'time': '2019-01-31T00:05:00.000000000Z',
#    'ask': {'o': '1.14909', 'h': '1.14957', 'l': '1.14909', 'c': '1.14957'}},
#   {'complete': True,
#    'volume': 74,
#    'time': '2019-01-31T00:10:00.000000000Z',
#    'ask': {'o': '1.14959', 'h': '1.14966', 'l': '1.14910', 'c': '1.14936'}},
#   {'complete': True,
#    'volume': 48,
#    'time': '2019-01-31T00:15:00.000000000Z',
#    'ask': {'o': '1.14933', 'h': '1.14933', 'l': '1.14900', 'c': '1.14918'}},
#   {'complete': True,
#    'volume': 66,
#    'time': '2019-01-31T00:20:00.000000000Z',
#    'ask': {'o': '1.14920', 'h': '1.14955', 'l': '1.14920', 'c': '1.14940'}},
#   {'complete': True,
#    'volume': 34,
#    'time': '2019-01-31T00:25:00.000000000Z',
#    'ask': {'o': '1.14942', 'h': '1.14948', 'l': '1.14929', 'c': '1.14941'}},
#   {'complete': True,
#    'volume': 49,
#    'time': '2019-01-31T00:30:00.000000000Z',
#    'ask': {'o': '1.14943', 'h': '1.14952', 'l': '1.14924', 'c': '1.14929'}},
#   {'complete': True,
#    'volume': 32,
#    'time': '2019-01-31T00:35:00.000000000Z',
#    'ask': {'o': '1.14926', 'h': '1.14928', 'l': '1.14910', 'c': '1.14914'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2019-01-31T00:40:00.000000000Z',
#    'ask': {'o': '1.14912', 'h': '1.14912', 'l': '1.14885', 'c': '1.14890'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2019-01-31T00:45:00.000000000Z',
#    'ask': {'o': '1.14888', 'h': '1.14888', 'l': '1.14875', 'c': '1.14882'}},
#   {'complete': True,
#    'volume': 78,
#    'time': '2019-01-31T00:50:00.000000000Z',
#    'ask': {'o': '1.14884', 'h': '1.14913', 'l': '1.14884', 'c': '1.14897'}},
#   {'complete': True,
#    'volume': 57,
#    'time': '2019-01-31T00:55:00.000000000Z',
#    'ask': {'o': '1.14895', 'h': '1.14904', 'l': '1.14883', 'c': '1.14895'}},
#   {'complete': True,
#    'volume': 83,
#    'time': '2019-01-31T01:00:00.000000000Z',
#    'ask': {'o': '1.14891', 'h': '1.14915', 'l': '1.14883', 'c': '1.14909'}},
#   {'complete': True,
#    'volume': 29,
#    'time': '2019-01-31T01:05:00.000000000Z',
#    'ask': {'o': '1.14911', 'h': '1.14936', 'l': '1.14911', 'c': '1.14936'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2019-01-31T01:10:00.000000000Z',
#    'ask': {'o': '1.14934', 'h': '1.14947', 'l': '1.14934', 'c': '1.14937'}},
#   {'complete': True,
#    'volume': 42,
#    'time': '2019-01-31T01:15:00.000000000Z',
#    'ask': {'o': '1.14940', 'h': '1.14945', 'l': '1.14929', 'c': '1.14941'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2019-01-31T01:20:00.000000000Z',
#    'ask': {'o': '1.14939', 'h': '1.14946', 'l': '1.14934', 'c': '1.14946'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2019-01-31T01:25:00.000000000Z',
#    'ask': {'o': '1.14944', 'h': '1.14944', 'l': '1.14927', 'c': '1.14930'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2019-01-31T01:30:00.000000000Z',
#    'ask': {'o': '1.14926', 'h': '1.14944', 'l': '1.14914', 'c': '1.14918'}},
#   {'complete': True,
#    'volume': 45,
#    'time': '2019-01-31T01:35:00.000000000Z',
#    'ask': {'o': '1.14916', 'h': '1.14951', 'l': '1.14913', 'c': '1.14948'}},
#   {'complete': True,
#    'volume': 36,
#    'time': '2019-01-31T01:40:00.000000000Z',
#    'ask': {'o': '1.14946', 'h': '1.14954', 'l': '1.14937', 'c': '1.14942'}},
#   {'complete': True,
#    'volume': 15,
#    'time': '2019-01-31T01:45:00.000000000Z',
#    'ask': {'o': '1.14940', 'h': '1.14949', 'l': '1.14937', 'c': '1.14940'}},
#   {'complete': True,
#    'volume': 23,
#    'time': '2019-01-31T01:50:00.000000000Z',
#    'ask': {'o': '1.14937', 'h': '1.14951', 'l': '1.14933', 'c': '1.14944'}},
#   {'complete': True,
#    'volume': 41,
#    'time': '2019-01-31T01:55:00.000000000Z',
#    'ask': {'o': '1.14947', 'h': '1.14949', 'l': '1.14930', 'c': '1.14942'}},
#   {'complete': True,
#    'volume': 36,
#    'time': '2019-01-31T02:00:00.000000000Z',
#    'ask': {'o': '1.14939', 'h': '1.14944', 'l': '1.14926', 'c': '1.14935'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2019-01-31T02:05:00.000000000Z',
#    'ask': {'o': '1.14938', 'h': '1.14955', 'l': '1.14936', 'c': '1.14955'}},
#   {'complete': True,
#    'volume': 43,
#    'time': '2019-01-31T02:10:00.000000000Z',
#    'ask': {'o': '1.14957', 'h': '1.14964', 'l': '1.14944', 'c': '1.14962'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2019-01-31T02:15:00.000000000Z',
#    'ask': {'o': '1.14960', 'h': '1.14974', 'l': '1.14959', 'c': '1.14961'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2019-01-31T02:20:00.000000000Z',
#    'ask': {'o': '1.14958', 'h': '1.14964', 'l': '1.14950', 'c': '1.14950'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2019-01-31T02:25:00.000000000Z',
#    'ask': {'o': '1.14953', 'h': '1.14966', 'l': '1.14953', 'c': '1.14962'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2019-01-31T02:30:00.000000000Z',
#    'ask': {'o': '1.14960', 'h': '1.14960', 'l': '1.14951', 'c': '1.14951'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2019-01-31T02:35:00.000000000Z',
#    'ask': {'o': '1.14954', 'h': '1.14956', 'l': '1.14932', 'c': '1.14941'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2019-01-31T02:40:00.000000000Z',
#    'ask': {'o': '1.14944', 'h': '1.14965', 'l': '1.14941', 'c': '1.14960'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2019-01-31T02:45:00.000000000Z',
#    'ask': {'o': '1.14957', 'h': '1.14994', 'l': '1.14953', 'c': '1.14989'}},
#   {'complete': True,
#    'volume': 90,
#    'time': '2019-01-31T02:50:00.000000000Z',
#    'ask': {'o': '1.14992', 'h': '1.15056', 'l': '1.14992', 'c': '1.15046'}},
#   {'complete': True,
#    'volume': 56,
#    'time': '2019-01-31T02:55:00.000000000Z',
#    'ask': {'o': '1.15044', 'h': '1.15050', 'l': '1.15030', 'c': '1.15039'}},
#   {'complete': True,
#    'volume': 62,
#    'time': '2019-01-31T03:00:00.000000000Z',
#    'ask': {'o': '1.15042', 'h': '1.15063', 'l': '1.15027', 'c': '1.15033'}},
#   {'complete': True,
#    'volume': 34,
#    'time': '2019-01-31T03:05:00.000000000Z',
#    'ask': {'o': '1.15034', 'h': '1.15052', 'l': '1.15021', 'c': '1.15045'}},
#   {'complete': True,
#    'volume': 58,
#    'time': '2019-01-31T03:10:00.000000000Z',
#    'ask': {'o': '1.15047', 'h': '1.15086', 'l': '1.15045', 'c': '1.15067'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2019-01-31T03:15:00.000000000Z',
#    'ask': {'o': '1.15064', 'h': '1.15067', 'l': '1.15043', 'c': '1.15049'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2019-01-31T03:20:00.000000000Z',
#    'ask': {'o': '1.15045', 'h': '1.15047', 'l': '1.15038', 'c': '1.15045'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2019-01-31T03:25:00.000000000Z',
#    'ask': {'o': '1.15042', 'h': '1.15052', 'l': '1.15030', 'c': '1.15052'}},
#   {'complete': True,
#    'volume': 32,
#    'time': '2019-01-31T03:30:00.000000000Z',
#    'ask': {'o': '1.15055', 'h': '1.15067', 'l': '1.15054', 'c': '1.15057'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-01-31T03:35:00.000000000Z',
#    'ask': {'o': '1.15055', 'h': '1.15063', 'l': '1.15052', 'c': '1.15059'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2019-01-31T03:40:00.000000000Z',
#    'ask': {'o': '1.15056', 'h': '1.15061', 'l': '1.15033', 'c': '1.15036'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2019-01-31T03:45:00.000000000Z',
#    'ask': {'o': '1.15034', 'h': '1.15034', 'l': '1.15025', 'c': '1.15026'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2019-01-31T03:50:00.000000000Z',
#    'ask': {'o': '1.15028', 'h': '1.15032', 'l': '1.15024', 'c': '1.15032'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2019-01-31T03:55:00.000000000Z',
#    'ask': {'o': '1.15030', 'h': '1.15032', 'l': '1.15020', 'c': '1.15025'}},
#   {'complete': True,
#    'volume': 28,
#    'time': '2019-01-31T04:00:00.000000000Z',
#    'ask': {'o': '1.15023', 'h': '1.15031', 'l': '1.15017', 'c': '1.15031'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2019-01-31T04:05:00.000000000Z',
#    'ask': {'o': '1.15028', 'h': '1.15028', 'l': '1.15019', 'c': '1.15026'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2019-01-31T04:10:00.000000000Z',
#    'ask': {'o': '1.15029', 'h': '1.15033', 'l': '1.15022', 'c': '1.15033'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2019-01-31T04:15:00.000000000Z',
#    'ask': {'o': '1.15030', 'h': '1.15039', 'l': '1.15030', 'c': '1.15039'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2019-01-31T04:20:00.000000000Z',
#    'ask': {'o': '1.15042', 'h': '1.15044', 'l': '1.15030', 'c': '1.15044'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2019-01-31T04:25:00.000000000Z',
#    'ask': {'o': '1.15042', 'h': '1.15051', 'l': '1.15042', 'c': '1.15045'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2019-01-31T04:30:00.000000000Z',
#    'ask': {'o': '1.15047', 'h': '1.15058', 'l': '1.15040', 'c': '1.15058'}},
#   {'complete': True,
#    'volume': 46,
#    'time': '2019-01-31T04:35:00.000000000Z',
#    'ask': {'o': '1.15060', 'h': '1.15070', 'l': '1.15034', 'c': '1.15044'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2019-01-31T04:40:00.000000000Z',
#    'ask': {'o': '1.15042', 'h': '1.15046', 'l': '1.15039', 'c': '1.15042'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2019-01-31T04:45:00.000000000Z',
#    'ask': {'o': '1.15044', 'h': '1.15047', 'l': '1.15034', 'c': '1.15034'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2019-01-31T04:50:00.000000000Z',
#    'ask': {'o': '1.15038', 'h': '1.15056', 'l': '1.15035', 'c': '1.15051'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2019-01-31T04:55:00.000000000Z',
#    'ask': {'o': '1.15048', 'h': '1.15048', 'l': '1.15031', 'c': '1.15033'}},
#   {'complete': True,
#    'volume': 22,
#    'time': '2019-01-31T05:00:00.000000000Z',
#    'ask': {'o': '1.15036', 'h': '1.15042', 'l': '1.15032', 'c': '1.15035'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2019-01-31T05:05:00.000000000Z',
#    'ask': {'o': '1.15038', 'h': '1.15050', 'l': '1.15038', 'c': '1.15046'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-01-31T05:10:00.000000000Z',
#    'ask': {'o': '1.15048', 'h': '1.15055', 'l': '1.15048', 'c': '1.15050'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-01-31T05:15:00.000000000Z',
#    'ask': {'o': '1.15048', 'h': '1.15055', 'l': '1.15043', 'c': '1.15050'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-01-31T05:20:00.000000000Z',
#    'ask': {'o': '1.15052', 'h': '1.15055', 'l': '1.15046', 'c': '1.15046'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2019-01-31T05:25:00.000000000Z',
#    'ask': {'o': '1.15044', 'h': '1.15062', 'l': '1.15041', 'c': '1.15045'}},
#   {'complete': True,
#    'volume': 28,
#    'time': '2019-01-31T05:30:00.000000000Z',
#    'ask': {'o': '1.15041', 'h': '1.15045', 'l': '1.15031', 'c': '1.15035'}},
#   {'complete': True,
#    'volume': 24,
#    'time': '2019-01-31T05:35:00.000000000Z',
#    'ask': {'o': '1.15037', 'h': '1.15061', 'l': '1.15037', 'c': '1.15049'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2019-01-31T05:40:00.000000000Z',
#    'ask': {'o': '1.15051', 'h': '1.15097', 'l': '1.15051', 'c': '1.15092'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2019-01-31T05:45:00.000000000Z',
#    'ask': {'o': '1.15089', 'h': '1.15089', 'l': '1.15076', 'c': '1.15077'}},
#   {'complete': True,
#    'volume': 24,
#    'time': '2019-01-31T05:50:00.000000000Z',
#    'ask': {'o': '1.15075', 'h': '1.15075', 'l': '1.15041', 'c': '1.15041'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2019-01-31T05:55:00.000000000Z',
#    'ask': {'o': '1.15038', 'h': '1.15058', 'l': '1.15037', 'c': '1.15058'}},
#   {'complete': True,
#    'volume': 53,
#    'time': '2019-01-31T06:00:00.000000000Z',
#    'ask': {'o': '1.15058', 'h': '1.15064', 'l': '1.15038', 'c': '1.15040'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2019-01-31T06:05:00.000000000Z',
#    'ask': {'o': '1.15038', 'h': '1.15040', 'l': '1.15025', 'c': '1.15027'}},
#   {'complete': True,
#    'volume': 72,
#    'time': '2019-01-31T06:10:00.000000000Z',
#    'ask': {'o': '1.15029', 'h': '1.15029', 'l': '1.14990', 'c': '1.15003'}},
#   {'complete': True,
#    'volume': 38,
#    'time': '2019-01-31T06:15:00.000000000Z',
#    'ask': {'o': '1.15005', 'h': '1.15039', 'l': '1.15005', 'c': '1.15039'}},
#   {'complete': True,
#    'volume': 36,
#    'time': '2019-01-31T06:20:00.000000000Z',
#    'ask': {'o': '1.15037', 'h': '1.15045', 'l': '1.15024', 'c': '1.15035'}},
#   {'complete': True,
#    'volume': 95,
#    'time': '2019-01-31T06:25:00.000000000Z',
#    'ask': {'o': '1.15037', 'h': '1.15048', 'l': '1.14982', 'c': '1.14983'}},
#   {'complete': True,
#    'volume': 45,
#    'time': '2019-01-31T06:30:00.000000000Z',
#    'ask': {'o': '1.14982', 'h': '1.15006', 'l': '1.14982', 'c': '1.14991'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2019-01-31T06:35:00.000000000Z',
#    'ask': {'o': '1.14990', 'h': '1.15025', 'l': '1.14983', 'c': '1.15011'}},
#   {'complete': True,
#    'volume': 24,
#    'time': '2019-01-31T06:40:00.000000000Z',
#    'ask': {'o': '1.15010', 'h': '1.15010', 'l': '1.14992', 'c': '1.14992'}},
#   {'complete': True,
#    'volume': 23,
#    'time': '2019-01-31T06:45:00.000000000Z',
#    'ask': {'o': '1.14995', 'h': '1.15010', 'l': '1.14992', 'c': '1.15010'}},
#   {'complete': True,
#    'volume': 59,
#    'time': '2019-01-31T06:50:00.000000000Z',
#    'ask': {'o': '1.15012', 'h': '1.15021', 'l': '1.14983', 'c': '1.15009'}},
#   {'complete': True,
#    'volume': 54,
#    'time': '2019-01-31T06:55:00.000000000Z',
#    'ask': {'o': '1.15011', 'h': '1.15022', 'l': '1.15000', 'c': '1.15016'}},
#   {'complete': True,
#    'volume': 145,
#    'time': '2019-01-31T07:00:00.000000000Z',
#    'ask': {'o': '1.15013', 'h': '1.15022', 'l': '1.14961', 'c': '1.15008'}},
#   {'complete': True,
#    'volume': 101,
#    'time': '2019-01-31T07:05:00.000000000Z',
#    'ask': {'o': '1.15009', 'h': '1.15066', 'l': '1.15009', 'c': '1.15024'}},
#   {'complete': True,
#    'volume': 121,
#    'time': '2019-01-31T07:10:00.000000000Z',
#    'ask': {'o': '1.15022', 'h': '1.15032', 'l': '1.14963', 'c': '1.14979'}},
#   {'complete': True,
#    'volume': 159,
#    'time': '2019-01-31T07:15:00.000000000Z',
#    'ask': {'o': '1.14978', 'h': '1.15038', 'l': '1.14970', 'c': '1.15029'}},
#   {'complete': True,
#    'volume': 118,
#    'time': '2019-01-31T07:20:00.000000000Z',
#    'ask': {'o': '1.15031', 'h': '1.15067', 'l': '1.15031', 'c': '1.15051'}},
#   {'complete': True,
#    'volume': 229,
#    'time': '2019-01-31T07:25:00.000000000Z',
#    'ask': {'o': '1.15053', 'h': '1.15150', 'l': '1.15053', 'c': '1.15140'}},
#   {'complete': True,
#    'volume': 119,
#    'time': '2019-01-31T07:30:00.000000000Z',
#    'ask': {'o': '1.15142', 'h': '1.15145', 'l': '1.15103', 'c': '1.15107'}},
#   {'complete': True,
#    'volume': 105,
#    'time': '2019-01-31T07:35:00.000000000Z',
#    'ask': {'o': '1.15105', 'h': '1.15116', 'l': '1.15080', 'c': '1.15113'}},
#   {'complete': True,
#    'volume': 138,
#    'time': '2019-01-31T07:40:00.000000000Z',
#    'ask': {'o': '1.15110', 'h': '1.15124', 'l': '1.15084', 'c': '1.15110'}},
#   {'complete': True,
#    'volume': 135,
#    'time': '2019-01-31T07:45:00.000000000Z',
#    'ask': {'o': '1.15114', 'h': '1.15134', 'l': '1.15097', 'c': '1.15123'}},
#   {'complete': True,
#    'volume': 153,
#    'time': '2019-01-31T07:50:00.000000000Z',
#    'ask': {'o': '1.15121', 'h': '1.15121', 'l': '1.15044', 'c': '1.15047'}},
#   {'complete': True,
#    'volume': 196,
#    'time': '2019-01-31T07:55:00.000000000Z',
#    'ask': {'o': '1.15050', 'h': '1.15052', 'l': '1.14966', 'c': '1.14968'}},
#   {'complete': True,
#    'volume': 456,
#    'time': '2019-01-31T08:00:00.000000000Z',
#    'ask': {'o': '1.14970', 'h': '1.15013', 'l': '1.14865', 'c': '1.14958'}},
#   {'complete': True,
#    'volume': 231,
#    'time': '2019-01-31T08:05:00.000000000Z',
#    'ask': {'o': '1.14956', 'h': '1.15033', 'l': '1.14953', 'c': '1.15030'}},
#   {'complete': True,
#    'volume': 150,
#    'time': '2019-01-31T08:10:00.000000000Z',
#    'ask': {'o': '1.15028', 'h': '1.15057', 'l': '1.15022', 'c': '1.15050'}},
#   {'complete': True,
#    'volume': 89,
#    'time': '2019-01-31T08:15:00.000000000Z',
#    'ask': {'o': '1.15053', 'h': '1.15077', 'l': '1.15041', 'c': '1.15069'}},
#   {'complete': True,
#    'volume': 75,
#    'time': '2019-01-31T08:20:00.000000000Z',
#    'ask': {'o': '1.15072', 'h': '1.15093', 'l': '1.15051', 'c': '1.15057'}},
#   {'complete': True,
#    'volume': 129,
#    'time': '2019-01-31T08:25:00.000000000Z',
#    'ask': {'o': '1.15060', 'h': '1.15079', 'l': '1.15039', 'c': '1.15052'}},
#   {'complete': True,
#    'volume': 123,
#    'time': '2019-01-31T08:30:00.000000000Z',
#    'ask': {'o': '1.15049', 'h': '1.15058', 'l': '1.15015', 'c': '1.15015'}},
#   {'complete': True,
#    'volume': 169,
#    'time': '2019-01-31T08:35:00.000000000Z',
#    'ask': {'o': '1.15012', 'h': '1.15015', 'l': '1.14959', 'c': '1.14964'}},
#   {'complete': True,
#    'volume': 121,
#    'time': '2019-01-31T08:40:00.000000000Z',
#    'ask': {'o': '1.14967', 'h': '1.14999', 'l': '1.14960', 'c': '1.14965'}},
#   {'complete': True,
#    'volume': 113,
#    'time': '2019-01-31T08:45:00.000000000Z',
#    'ask': {'o': '1.14967', 'h': '1.14970', 'l': '1.14925', 'c': '1.14953'}},
#   {'complete': True,
#    'volume': 57,
#    'time': '2019-01-31T08:50:00.000000000Z',
#    'ask': {'o': '1.14955', 'h': '1.14958', 'l': '1.14938', 'c': '1.14949'}},
#   {'complete': True,
#    'volume': 118,
#    'time': '2019-01-31T08:55:00.000000000Z',
#    'ask': {'o': '1.14947', 'h': '1.14947', 'l': '1.14910', 'c': '1.14922'}},
#   {'complete': True,
#    'volume': 186,
#    'time': '2019-01-31T09:00:00.000000000Z',
#    'ask': {'o': '1.14925', 'h': '1.14946', 'l': '1.14889', 'c': '1.14911'}},
#   {'complete': True,
#    'volume': 96,
#    'time': '2019-01-31T09:05:00.000000000Z',
#    'ask': {'o': '1.14910', 'h': '1.14922', 'l': '1.14896', 'c': '1.14896'}},
#   {'complete': True,
#    'volume': 106,
#    'time': '2019-01-31T09:10:00.000000000Z',
#    'ask': {'o': '1.14894', 'h': '1.14912', 'l': '1.14871', 'c': '1.14904'}},
#   {'complete': True,
#    'volume': 112,
#    'time': '2019-01-31T09:15:00.000000000Z',
#    'ask': {'o': '1.14901', 'h': '1.14914', 'l': '1.14879', 'c': '1.14888'}},
#   {'complete': True,
#    'volume': 151,
#    'time': '2019-01-31T09:20:00.000000000Z',
#    'ask': {'o': '1.14886', 'h': '1.14924', 'l': '1.14863', 'c': '1.14919'}},
#   {'complete': True,
#    'volume': 101,
#    'time': '2019-01-31T09:25:00.000000000Z',
#    'ask': {'o': '1.14921', 'h': '1.14934', 'l': '1.14910', 'c': '1.14919'}},
#   {'complete': True,
#    'volume': 182,
#    'time': '2019-01-31T09:30:00.000000000Z',
#    'ask': {'o': '1.14917', 'h': '1.14926', 'l': '1.14869', 'c': '1.14877'}},
#   {'complete': True,
#    'volume': 123,
#    'time': '2019-01-31T09:35:00.000000000Z',
#    'ask': {'o': '1.14880', 'h': '1.14911', 'l': '1.14876', 'c': '1.14911'}},
#   {'complete': True,
#    'volume': 178,
#    'time': '2019-01-31T09:40:00.000000000Z',
#    'ask': {'o': '1.14913', 'h': '1.14945', 'l': '1.14910', 'c': '1.14924'}},
#   {'complete': True,
#    'volume': 108,
#    'time': '2019-01-31T09:45:00.000000000Z',
#    'ask': {'o': '1.14922', 'h': '1.14932', 'l': '1.14906', 'c': '1.14909'}},
#   {'complete': True,
#    'volume': 104,
#    'time': '2019-01-31T09:50:00.000000000Z',
#    'ask': {'o': '1.14907', 'h': '1.14929', 'l': '1.14899', 'c': '1.14906'}},
#   {'complete': True,
#    'volume': 154,
#    'time': '2019-01-31T09:55:00.000000000Z',
#    'ask': {'o': '1.14909', 'h': '1.14924', 'l': '1.14838', 'c': '1.14855'}},
#   {'complete': True,
#    'volume': 274,
#    'time': '2019-01-31T10:00:00.000000000Z',
#    'ask': {'o': '1.14858', 'h': '1.14881', 'l': '1.14783', 'c': '1.14786'}},
#   {'complete': True,
#    'volume': 162,
#    'time': '2019-01-31T10:05:00.000000000Z',
#    'ask': {'o': '1.14783', 'h': '1.14857', 'l': '1.14783', 'c': '1.14819'}},
#   {'complete': True,
#    'volume': 185,
#    'time': '2019-01-31T10:10:00.000000000Z',
#    'ask': {'o': '1.14817', 'h': '1.14862', 'l': '1.14814', 'c': '1.14856'}},
#   {'complete': True,
#    'volume': 86,
#    'time': '2019-01-31T10:15:00.000000000Z',
#    'ask': {'o': '1.14858', 'h': '1.14867', 'l': '1.14850', 'c': '1.14850'}},
#   {'complete': True,
#    'volume': 90,
#    'time': '2019-01-31T10:20:00.000000000Z',
#    'ask': {'o': '1.14852', 'h': '1.14866', 'l': '1.14813', 'c': '1.14821'}},
#   {'complete': True,
#    'volume': 152,
#    'time': '2019-01-31T10:25:00.000000000Z',
#    'ask': {'o': '1.14818', 'h': '1.14823', 'l': '1.14790', 'c': '1.14806'}},
#   {'complete': True,
#    'volume': 190,
#    'time': '2019-01-31T10:30:00.000000000Z',
#    'ask': {'o': '1.14808', 'h': '1.14815', 'l': '1.14730', 'c': '1.14752'}},
#   {'complete': True,
#    'volume': 185,
#    'time': '2019-01-31T10:35:00.000000000Z',
#    'ask': {'o': '1.14754', 'h': '1.14796', 'l': '1.14754', 'c': '1.14770'}},
#   {'complete': True,
#    'volume': 151,
#    'time': '2019-01-31T10:40:00.000000000Z',
#    'ask': {'o': '1.14772', 'h': '1.14781', 'l': '1.14723', 'c': '1.14726'}},
#   {'complete': True,
#    'volume': 125,
#    'time': '2019-01-31T10:45:00.000000000Z',
#    'ask': {'o': '1.14728', 'h': '1.14742', 'l': '1.14725', 'c': '1.14733'}},
#   {'complete': True,
#    'volume': 110,
#    'time': '2019-01-31T10:50:00.000000000Z',
#    'ask': {'o': '1.14729', 'h': '1.14748', 'l': '1.14728', 'c': '1.14743'}},
#   {'complete': True,
#    'volume': 104,
#    'time': '2019-01-31T10:55:00.000000000Z',
#    'ask': {'o': '1.14746', 'h': '1.14780', 'l': '1.14743', 'c': '1.14775'}},
#   {'complete': True,
#    'volume': 132,
#    'time': '2019-01-31T11:00:00.000000000Z',
#    'ask': {'o': '1.14773', 'h': '1.14794', 'l': '1.14766', 'c': '1.14787'}},
#   {'complete': True,
#    'volume': 87,
#    'time': '2019-01-31T11:05:00.000000000Z',
#    'ask': {'o': '1.14790', 'h': '1.14808', 'l': '1.14781', 'c': '1.14806'}},
#   {'complete': True,
#    'volume': 85,
#    'time': '2019-01-31T11:10:00.000000000Z',
#    'ask': {'o': '1.14803', 'h': '1.14838', 'l': '1.14801', 'c': '1.14821'}},
#   {'complete': True,
#    'volume': 92,
#    'time': '2019-01-31T11:15:00.000000000Z',
#    'ask': {'o': '1.14818', 'h': '1.14845', 'l': '1.14818', 'c': '1.14834'}},
#   {'complete': True,
#    'volume': 72,
#    'time': '2019-01-31T11:20:00.000000000Z',
#    'ask': {'o': '1.14836', 'h': '1.14843', 'l': '1.14804', 'c': '1.14817'}},
#   {'complete': True,
#    'volume': 110,
#    'time': '2019-01-31T11:25:00.000000000Z',
#    'ask': {'o': '1.14814', 'h': '1.14839', 'l': '1.14808', 'c': '1.14836'}},
#   {'complete': True,
#    'volume': 77,
#    'time': '2019-01-31T11:30:00.000000000Z',
#    'ask': {'o': '1.14834', 'h': '1.14852', 'l': '1.14825', 'c': '1.14852'}},
#   {'complete': True,
#    'volume': 73,
#    'time': '2019-01-31T11:35:00.000000000Z',
#    'ask': {'o': '1.14850', 'h': '1.14866', 'l': '1.14849', 'c': '1.14854'}},
#   {'complete': True,
#    'volume': 111,
#    'time': '2019-01-31T11:40:00.000000000Z',
#    'ask': {'o': '1.14856', 'h': '1.14884', 'l': '1.14856', 'c': '1.14867'}},
#   {'complete': True,
#    'volume': 62,
#    'time': '2019-01-31T11:45:00.000000000Z',
#    'ask': {'o': '1.14865', 'h': '1.14888', 'l': '1.14860', 'c': '1.14882'}},
#   {'complete': True,
#    'volume': 80,
#    'time': '2019-01-31T11:50:00.000000000Z',
#    'ask': {'o': '1.14879', 'h': '1.14894', 'l': '1.14877', 'c': '1.14883'}},
#   {'complete': True,
#    'volume': 82,
#    'time': '2019-01-31T11:55:00.000000000Z',
#    'ask': {'o': '1.14886', 'h': '1.14901', 'l': '1.14878', 'c': '1.14878'}},
#   {'complete': True,
#    'volume': 66,
#    'time': '2019-01-31T12:00:00.000000000Z',
#    'ask': {'o': '1.14881', 'h': '1.14883', 'l': '1.14865', 'c': '1.14875'}},
#   {'complete': True,
#    'volume': 86,
#    'time': '2019-01-31T12:05:00.000000000Z',
#    'ask': {'o': '1.14872', 'h': '1.14893', 'l': '1.14864', 'c': '1.14869'}},
#   {'complete': True,
#    'volume': 124,
#    'time': '2019-01-31T12:10:00.000000000Z',
#    'ask': {'o': '1.14866', 'h': '1.14890', 'l': '1.14855', 'c': '1.14890'}},
#   {'complete': True,
#    'volume': 70,
#    'time': '2019-01-31T12:15:00.000000000Z',
#    'ask': {'o': '1.14888', 'h': '1.14896', 'l': '1.14874', 'c': '1.14888'}},
#   {'complete': True,
#    'volume': 157,
#    'time': '2019-01-31T12:20:00.000000000Z',
#    'ask': {'o': '1.14885', 'h': '1.14944', 'l': '1.14885', 'c': '1.14936'}},
#   {'complete': True,
#    'volume': 88,
#    'time': '2019-01-31T12:25:00.000000000Z',
#    'ask': {'o': '1.14933', 'h': '1.14951', 'l': '1.14928', 'c': '1.14930'}},
#   {'complete': True,
#    'volume': 74,
#    'time': '2019-01-31T12:30:00.000000000Z',
#    'ask': {'o': '1.14928', 'h': '1.14955', 'l': '1.14915', 'c': '1.14950'}},
#   {'complete': True,
#    'volume': 55,
#    'time': '2019-01-31T12:35:00.000000000Z',
#    'ask': {'o': '1.14948', 'h': '1.14956', 'l': '1.14928', 'c': '1.14934'}},
#   {'complete': True,
#    'volume': 64,
#    'time': '2019-01-31T12:40:00.000000000Z',
#    'ask': {'o': '1.14936', 'h': '1.14957', 'l': '1.14933', 'c': '1.14954'}},
#   {'complete': True,
#    'volume': 90,
#    'time': '2019-01-31T12:45:00.000000000Z',
#    'ask': {'o': '1.14952', 'h': '1.14965', 'l': '1.14928', 'c': '1.14950'}},
#   {'complete': True,
#    'volume': 89,
#    'time': '2019-01-31T12:50:00.000000000Z',
#    'ask': {'o': '1.14947', 'h': '1.14950', 'l': '1.14918', 'c': '1.14929'}},
#   {'complete': True,
#    'volume': 138,
#    'time': '2019-01-31T12:55:00.000000000Z',
#    'ask': {'o': '1.14926', 'h': '1.14935', 'l': '1.14881', 'c': '1.14934'}},
#   {'complete': True,
#    'volume': 118,
#    'time': '2019-01-31T13:00:00.000000000Z',
#    'ask': {'o': '1.14935', 'h': '1.14948', 'l': '1.14900', 'c': '1.14902'}},
#   {'complete': True,
#    'volume': 120,
#    'time': '2019-01-31T13:05:00.000000000Z',
#    'ask': {'o': '1.14905', 'h': '1.14918', 'l': '1.14866', 'c': '1.14866'}},
#   {'complete': True,
#    'volume': 115,
#    'time': '2019-01-31T13:10:00.000000000Z',
#    'ask': {'o': '1.14868', 'h': '1.14890', 'l': '1.14857', 'c': '1.14888'}},
#   {'complete': True,
#    'volume': 123,
#    'time': '2019-01-31T13:15:00.000000000Z',
#    'ask': {'o': '1.14886', 'h': '1.14921', 'l': '1.14873', 'c': '1.14902'}},
#   {'complete': True,
#    'volume': 109,
#    'time': '2019-01-31T13:20:00.000000000Z',
#    'ask': {'o': '1.14899', 'h': '1.14937', 'l': '1.14889', 'c': '1.14913'}},
#   {'complete': True,
#    'volume': 82,
#    'time': '2019-01-31T13:25:00.000000000Z',
#    'ask': {'o': '1.14916', 'h': '1.14916', 'l': '1.14869', 'c': '1.14873'}},
#   {'complete': True,
#    'volume': 269,
#    'time': '2019-01-31T13:30:00.000000000Z',
#    'ask': {'o': '1.14881', 'h': '1.14945', 'l': '1.14881', 'c': '1.14923'}},
#   {'complete': True,
#    'volume': 182,
#    'time': '2019-01-31T13:35:00.000000000Z',
#    'ask': {'o': '1.14925', 'h': '1.14959', 'l': '1.14925', 'c': '1.14935'}},
#   {'complete': True,
#    'volume': 222,
#    'time': '2019-01-31T13:40:00.000000000Z',
#    'ask': {'o': '1.14933', 'h': '1.14950', 'l': '1.14914', 'c': '1.14932'}},
#   {'complete': True,
#    'volume': 210,
#    'time': '2019-01-31T13:45:00.000000000Z',
#    'ask': {'o': '1.14934', 'h': '1.14934', 'l': '1.14851', 'c': '1.14867'}},
#   {'complete': True,
#    'volume': 197,
#    'time': '2019-01-31T13:50:00.000000000Z',
#    'ask': {'o': '1.14865', 'h': '1.14930', 'l': '1.14862', 'c': '1.14915'}},
#   {'complete': True,
#    'volume': 142,
#    'time': '2019-01-31T13:55:00.000000000Z',
#    'ask': {'o': '1.14913', 'h': '1.14958', 'l': '1.14905', 'c': '1.14953'}},
#   {'complete': True,
#    'volume': 191,
#    'time': '2019-01-31T14:00:00.000000000Z',
#    'ask': {'o': '1.14950', 'h': '1.14960', 'l': '1.14890', 'c': '1.14904'}},
#   {'complete': True,
#    'volume': 167,
#    'time': '2019-01-31T14:05:00.000000000Z',
#    'ask': {'o': '1.14901', 'h': '1.14910', 'l': '1.14844', 'c': '1.14849'}},
#   {'complete': True,
#    'volume': 139,
#    'time': '2019-01-31T14:10:00.000000000Z',
#    'ask': {'o': '1.14852', 'h': '1.14882', 'l': '1.14829', 'c': '1.14876'}},
#   {'complete': True,
#    'volume': 131,
#    'time': '2019-01-31T14:15:00.000000000Z',
#    'ask': {'o': '1.14875', 'h': '1.14905', 'l': '1.14872', 'c': '1.14890'}},
#   {'complete': True,
#    'volume': 117,
#    'time': '2019-01-31T14:20:00.000000000Z',
#    'ask': {'o': '1.14893', 'h': '1.14941', 'l': '1.14893', 'c': '1.14933'}},
#   {'complete': True,
#    'volume': 97,
#    'time': '2019-01-31T14:25:00.000000000Z',
#    'ask': {'o': '1.14931', 'h': '1.14936', 'l': '1.14879', 'c': '1.14887'}},
#   {'complete': True,
#    'volume': 89,
#    'time': '2019-01-31T14:30:00.000000000Z',
#    'ask': {'o': '1.14890', 'h': '1.14918', 'l': '1.14885', 'c': '1.14910'}},
#   {'complete': True,
#    'volume': 86,
#    'time': '2019-01-31T14:35:00.000000000Z',
#    'ask': {'o': '1.14912', 'h': '1.14917', 'l': '1.14894', 'c': '1.14905'}},
#   {'complete': True,
#    'volume': 147,
#    'time': '2019-01-31T14:40:00.000000000Z',
#    'ask': {'o': '1.14902', 'h': '1.14903', 'l': '1.14859', 'c': '1.14875'}},
#   {'complete': True,
#    'volume': 191,
#    'time': '2019-01-31T14:45:00.000000000Z',
#    'ask': {'o': '1.14877', 'h': '1.14888', 'l': '1.14790', 'c': '1.14807'}},
#   {'complete': True,
#    'volume': 239,
#    'time': '2019-01-31T14:50:00.000000000Z',
#    'ask': {'o': '1.14811', 'h': '1.14832', 'l': '1.14778', 'c': '1.14812'}},
#   {'complete': True,
#    'volume': 131,
#    'time': '2019-01-31T14:55:00.000000000Z',
#    'ask': {'o': '1.14810', 'h': '1.14822', 'l': '1.14779', 'c': '1.14782'}},
#   {'complete': True,
#    'volume': 211,
#    'time': '2019-01-31T15:00:00.000000000Z',
#    'ask': {'o': '1.14780', 'h': '1.14809', 'l': '1.14752', 'c': '1.14763'}},
#   {'complete': True,
#    'volume': 112,
#    'time': '2019-01-31T15:05:00.000000000Z',
#    'ask': {'o': '1.14765', 'h': '1.14788', 'l': '1.14760', 'c': '1.14774'}},
#   {'complete': True,
#    'volume': 94,
#    'time': '2019-01-31T15:10:00.000000000Z',
#    'ask': {'o': '1.14775', 'h': '1.14798', 'l': '1.14774', 'c': '1.14791'}},
#   {'complete': True,
#    'volume': 91,
#    'time': '2019-01-31T15:15:00.000000000Z',
#    'ask': {'o': '1.14788', 'h': '1.14789', 'l': '1.14749', 'c': '1.14773'}},
#   {'complete': True,
#    'volume': 107,
#    'time': '2019-01-31T15:20:00.000000000Z',
#    'ask': {'o': '1.14771', 'h': '1.14822', 'l': '1.14764', 'c': '1.14819'}},
#   {'complete': True,
#    'volume': 108,
#    'time': '2019-01-31T15:25:00.000000000Z',
#    'ask': {'o': '1.14817', 'h': '1.14863', 'l': '1.14813', 'c': '1.14860'}},
#   {'complete': True,
#    'volume': 92,
#    'time': '2019-01-31T15:30:00.000000000Z',
#    'ask': {'o': '1.14862', 'h': '1.14889', 'l': '1.14852', 'c': '1.14853'}},
#   {'complete': True,
#    'volume': 76,
#    'time': '2019-01-31T15:35:00.000000000Z',
#    'ask': {'o': '1.14851', 'h': '1.14861', 'l': '1.14835', 'c': '1.14857'}},
#   {'complete': True,
#    'volume': 101,
#    'time': '2019-01-31T15:40:00.000000000Z',
#    'ask': {'o': '1.14854', 'h': '1.14898', 'l': '1.14844', 'c': '1.14875'}},
#   {'complete': True,
#    'volume': 141,
#    'time': '2019-01-31T15:45:00.000000000Z',
#    'ask': {'o': '1.14873', 'h': '1.14887', 'l': '1.14829', 'c': '1.14838'}},
#   {'complete': True,
#    'volume': 169,
#    'time': '2019-01-31T15:50:00.000000000Z',
#    'ask': {'o': '1.14836', 'h': '1.14858', 'l': '1.14801', 'c': '1.14852'}},
#   {'complete': True,
#    'volume': 442,
#    'time': '2019-01-31T15:55:00.000000000Z',
#    'ask': {'o': '1.14855', 'h': '1.14877', 'l': '1.14727', 'c': '1.14759'}},
#   {'complete': True,
#    'volume': 409,
#    'time': '2019-01-31T16:00:00.000000000Z',
#    'ask': {'o': '1.14762', 'h': '1.14793', 'l': '1.14691', 'c': '1.14746'}},
#   {'complete': True,
#    'volume': 270,
#    'time': '2019-01-31T16:05:00.000000000Z',
#    'ask': {'o': '1.14748', 'h': '1.14748', 'l': '1.14654', 'c': '1.14673'}},
#   {'complete': True,
#    'volume': 340,
#    'time': '2019-01-31T16:10:00.000000000Z',
#    'ask': {'o': '1.14671', 'h': '1.14674', 'l': '1.14573', 'c': '1.14614'}},
#   {'complete': True,
#    'volume': 193,
#    'time': '2019-01-31T16:15:00.000000000Z',
#    'ask': {'o': '1.14612', 'h': '1.14641', 'l': '1.14565', 'c': '1.14578'}},
#   {'complete': True,
#    'volume': 268,
#    'time': '2019-01-31T16:20:00.000000000Z',
#    'ask': {'o': '1.14575', 'h': '1.14593', 'l': '1.14474', 'c': '1.14511'}},
#   {'complete': True,
#    'volume': 212,
#    'time': '2019-01-31T16:25:00.000000000Z',
#    'ask': {'o': '1.14508', 'h': '1.14559', 'l': '1.14503', 'c': '1.14547'}},
#   {'complete': True,
#    'volume': 159,
#    'time': '2019-01-31T16:30:00.000000000Z',
#    'ask': {'o': '1.14550', 'h': '1.14570', 'l': '1.14512', 'c': '1.14552'}},
#   {'complete': True,
#    'volume': 135,
#    'time': '2019-01-31T16:35:00.000000000Z',
#    'ask': {'o': '1.14549', 'h': '1.14585', 'l': '1.14544', 'c': '1.14556'}},
#   {'complete': True,
#    'volume': 96,
#    'time': '2019-01-31T16:40:00.000000000Z',
#    'ask': {'o': '1.14559', 'h': '1.14564', 'l': '1.14524', 'c': '1.14542'}},
#   {'complete': True,
#    'volume': 122,
#    'time': '2019-01-31T16:45:00.000000000Z',
#    'ask': {'o': '1.14545', 'h': '1.14546', 'l': '1.14505', 'c': '1.14545'}},
#   {'complete': True,
#    'volume': 132,
#    'time': '2019-01-31T16:50:00.000000000Z',
#    'ask': {'o': '1.14544', 'h': '1.14544', 'l': '1.14512', 'c': '1.14512'}},
#   {'complete': True,
#    'volume': 139,
#    'time': '2019-01-31T16:55:00.000000000Z',
#    'ask': {'o': '1.14510', 'h': '1.14546', 'l': '1.14504', 'c': '1.14539'}},
#   {'complete': True,
#    'volume': 110,
#    'time': '2019-01-31T17:00:00.000000000Z',
#    'ask': {'o': '1.14537', 'h': '1.14579', 'l': '1.14526', 'c': '1.14572'}},
#   {'complete': True,
#    'volume': 115,
#    'time': '2019-01-31T17:05:00.000000000Z',
#    'ask': {'o': '1.14571', 'h': '1.14578', 'l': '1.14531', 'c': '1.14533'}},
#   {'complete': True,
#    'volume': 111,
#    'time': '2019-01-31T17:10:00.000000000Z',
#    'ask': {'o': '1.14531', 'h': '1.14550', 'l': '1.14462', 'c': '1.14462'}},
#   {'complete': True,
#    'volume': 271,
#    'time': '2019-01-31T17:15:00.000000000Z',
#    'ask': {'o': '1.14464', 'h': '1.14472', 'l': '1.14385', 'c': '1.14392'}},
#   {'complete': True,
#    'volume': 131,
#    'time': '2019-01-31T17:20:00.000000000Z',
#    'ask': {'o': '1.14390', 'h': '1.14409', 'l': '1.14366', 'c': '1.14397'}},
#   {'complete': True,
#    'volume': 108,
#    'time': '2019-01-31T17:25:00.000000000Z',
#    'ask': {'o': '1.14399', 'h': '1.14414', 'l': '1.14392', 'c': '1.14408'}},
#   {'complete': True,
#    'volume': 124,
#    'time': '2019-01-31T17:30:00.000000000Z',
# ...
#   {'complete': True,
#    'volume': 24,
#    'time': '2019-02-04T19:50:00.000000000Z',
#    'ask': {'o': '1.14338', 'h': '1.14346', 'l': '1.14326', 'c': '1.14328'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2019-02-04T19:55:00.000000000Z',
#    'ask': {'o': '1.14326', 'h': '1.14335', 'l': '1.14314', 'c': '1.14319'}},
#   {'complete': True,
#    'volume': 20,
#    'time': '2019-02-04T20:00:00.000000000Z',
#    'ask': {'o': '1.14323', 'h': '1.14335', 'l': '1.14323', 'c': '1.14335'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2019-02-04T20:05:00.000000000Z',
#    'ask': {'o': '1.14337', 'h': '1.14344', 'l': '1.14337', 'c': '1.14340'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-02-04T20:10:00.000000000Z',
#    'ask': {'o': '1.14338', 'h': '1.14342', 'l': '1.14333', 'c': '1.14340'}},
#   {'complete': True,
#    'volume': 20,
#    'time': '2019-02-04T20:15:00.000000000Z',
#    'ask': {'o': '1.14344', 'h': '1.14347', 'l': '1.14338', 'c': '1.14347'}},
#   {'complete': True,
#    'volume': 20,
#    'time': '2019-02-04T20:20:00.000000000Z',
#    'ask': {'o': '1.14345', 'h': '1.14352', 'l': '1.14340', 'c': '1.14352'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2019-02-04T20:25:00.000000000Z',
#    'ask': {'o': '1.14350', 'h': '1.14352', 'l': '1.14346', 'c': '1.14346'}},
#   {'complete': True,
#    'volume': 32,
#    'time': '2019-02-04T20:30:00.000000000Z',
#    'ask': {'o': '1.14343', 'h': '1.14354', 'l': '1.14341', 'c': '1.14349'}},
#   {'complete': True,
#    'volume': 15,
#    'time': '2019-02-04T20:35:00.000000000Z',
#    'ask': {'o': '1.14346', 'h': '1.14353', 'l': '1.14341', 'c': '1.14346'}},
#   {'complete': True,
#    'volume': 28,
#    'time': '2019-02-04T20:40:00.000000000Z',
#    'ask': {'o': '1.14349', 'h': '1.14358', 'l': '1.14349', 'c': '1.14350'}},
#   {'complete': True,
#    'volume': 23,
#    'time': '2019-02-04T20:45:00.000000000Z',
#    'ask': {'o': '1.14352', 'h': '1.14354', 'l': '1.14335', 'c': '1.14338'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2019-02-04T20:50:00.000000000Z',
#    'ask': {'o': '1.14337', 'h': '1.14340', 'l': '1.14329', 'c': '1.14334'}},
#   {'complete': True,
#    'volume': 56,
#    'time': '2019-02-04T20:55:00.000000000Z',
#    'ask': {'o': '1.14332', 'h': '1.14351', 'l': '1.14332', 'c': '1.14351'}},
#   {'complete': True,
#    'volume': 15,
#    'time': '2019-02-04T21:00:00.000000000Z',
#    'ask': {'o': '1.14354', 'h': '1.14358', 'l': '1.14347', 'c': '1.14347'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-02-04T21:05:00.000000000Z',
#    'ask': {'o': '1.14350', 'h': '1.14360', 'l': '1.14348', 'c': '1.14357'}},
#   {'complete': True,
#    'volume': 4,
#    'time': '2019-02-04T21:10:00.000000000Z',
#    'ask': {'o': '1.14359', 'h': '1.14362', 'l': '1.14357', 'c': '1.14362'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2019-02-04T21:15:00.000000000Z',
#    'ask': {'o': '1.14364', 'h': '1.14370', 'l': '1.14359', 'c': '1.14360'}},
#   {'complete': True,
#    'volume': 3,
#    'time': '2019-02-04T21:20:00.000000000Z',
#    'ask': {'o': '1.14357', 'h': '1.14357', 'l': '1.14352', 'c': '1.14352'}},
#   {'complete': True,
#    'volume': 17,
#    'time': '2019-02-04T21:25:00.000000000Z',
#    'ask': {'o': '1.14349', 'h': '1.14366', 'l': '1.14344', 'c': '1.14363'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-02-04T21:30:00.000000000Z',
#    'ask': {'o': '1.14361', 'h': '1.14363', 'l': '1.14357', 'c': '1.14362'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-02-04T21:35:00.000000000Z',
#    'ask': {'o': '1.14365', 'h': '1.14372', 'l': '1.14365', 'c': '1.14367'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2019-02-04T21:40:00.000000000Z',
#    'ask': {'o': '1.14366', 'h': '1.14376', 'l': '1.14366', 'c': '1.14371'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2019-02-04T21:45:00.000000000Z',
#    'ask': {'o': '1.14369', 'h': '1.14369', 'l': '1.14354', 'c': '1.14354'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-02-04T21:50:00.000000000Z',
#    'ask': {'o': '1.14355', 'h': '1.14366', 'l': '1.14351', 'c': '1.14365'}},
#   {'complete': True,
#    'volume': 41,
#    'time': '2019-02-04T21:55:00.000000000Z',
#    'ask': {'o': '1.14368', 'h': '1.14403', 'l': '1.14354', 'c': '1.14403'}},
#   {'complete': True,
#    'volume': 3,
#    'time': '2019-02-04T22:00:00.000000000Z',
#    'ask': {'o': '1.14403', 'h': '1.14407', 'l': '1.14403', 'c': '1.14407'}},
#   {'complete': True,
#    'volume': 1,
#    'time': '2019-02-04T22:05:00.000000000Z',
#    'ask': {'o': '1.14400', 'h': '1.14400', 'l': '1.14400', 'c': '1.14400'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2019-02-04T22:10:00.000000000Z',
#    'ask': {'o': '1.14395', 'h': '1.14395', 'l': '1.14382', 'c': '1.14388'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2019-02-04T22:15:00.000000000Z',
#    'ask': {'o': '1.14388', 'h': '1.14388', 'l': '1.14366', 'c': '1.14382'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2019-02-04T22:20:00.000000000Z',
#    'ask': {'o': '1.14380', 'h': '1.14384', 'l': '1.14367', 'c': '1.14384'}},
#   {'complete': True,
#    'volume': 27,
#    'time': '2019-02-04T22:25:00.000000000Z',
#    'ask': {'o': '1.14384', 'h': '1.14433', 'l': '1.14378', 'c': '1.14379'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2019-02-04T22:30:00.000000000Z',
#    'ask': {'o': '1.14376', 'h': '1.14378', 'l': '1.14373', 'c': '1.14378'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2019-02-04T22:35:00.000000000Z',
#    'ask': {'o': '1.14375', 'h': '1.14379', 'l': '1.14373', 'c': '1.14375'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2019-02-04T22:40:00.000000000Z',
#    'ask': {'o': '1.14378', 'h': '1.14381', 'l': '1.14376', 'c': '1.14378'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2019-02-04T22:45:00.000000000Z',
#    'ask': {'o': '1.14376', 'h': '1.14379', 'l': '1.14367', 'c': '1.14367'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-02-04T22:50:00.000000000Z',
#    'ask': {'o': '1.14372', 'h': '1.14379', 'l': '1.14369', 'c': '1.14377'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2019-02-04T22:55:00.000000000Z',
#    'ask': {'o': '1.14383', 'h': '1.14383', 'l': '1.14368', 'c': '1.14368'}},
#   {'complete': True,
#    'volume': 36,
#    'time': '2019-02-04T23:00:00.000000000Z',
#    'ask': {'o': '1.14367', 'h': '1.14393', 'l': '1.14365', 'c': '1.14365'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2019-02-04T23:05:00.000000000Z',
#    'ask': {'o': '1.14369', 'h': '1.14369', 'l': '1.14363', 'c': '1.14363'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2019-02-04T23:10:00.000000000Z',
#    'ask': {'o': '1.14361', 'h': '1.14363', 'l': '1.14357', 'c': '1.14361'}},
#   {'complete': True,
#    'volume': 7,
#    'time': '2019-02-04T23:15:00.000000000Z',
#    'ask': {'o': '1.14359', 'h': '1.14364', 'l': '1.14357', 'c': '1.14364'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2019-02-04T23:20:00.000000000Z',
#    'ask': {'o': '1.14361', 'h': '1.14365', 'l': '1.14355', 'c': '1.14361'}},
#   {'complete': True,
#    'volume': 15,
#    'time': '2019-02-04T23:25:00.000000000Z',
#    'ask': {'o': '1.14359', 'h': '1.14360', 'l': '1.14354', 'c': '1.14354'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2019-02-04T23:30:00.000000000Z',
#    'ask': {'o': '1.14356', 'h': '1.14376', 'l': '1.14356', 'c': '1.14373'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-02-04T23:35:00.000000000Z',
#    'ask': {'o': '1.14371', 'h': '1.14374', 'l': '1.14360', 'c': '1.14365'}},
#   {'complete': True,
#    'volume': 8,
#    'time': '2019-02-04T23:40:00.000000000Z',
#    'ask': {'o': '1.14366', 'h': '1.14375', 'l': '1.14365', 'c': '1.14375'}},
#   {'complete': True,
#    'volume': 21,
#    'time': '2019-02-04T23:45:00.000000000Z',
#    'ask': {'o': '1.14373', 'h': '1.14393', 'l': '1.14373', 'c': '1.14393'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2019-02-04T23:50:00.000000000Z',
#    'ask': {'o': '1.14389', 'h': '1.14389', 'l': '1.14371', 'c': '1.14371'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2019-02-04T23:55:00.000000000Z',
#    'ask': {'o': '1.14368', 'h': '1.14370', 'l': '1.14358', 'c': '1.14358'}},
#   {'complete': True,
#    'volume': 84,
#    'time': '2019-02-05T00:00:00.000000000Z',
#    'ask': {'o': '1.14356', 'h': '1.14373', 'l': '1.14339', 'c': '1.14355'}},
#   {'complete': True,
#    'volume': 33,
#    'time': '2019-02-05T00:05:00.000000000Z',
#    'ask': {'o': '1.14353', 'h': '1.14368', 'l': '1.14346', 'c': '1.14349'}},
#   {'complete': True,
#    'volume': 20,
#    'time': '2019-02-05T00:10:00.000000000Z',
#    'ask': {'o': '1.14352', 'h': '1.14363', 'l': '1.14352', 'c': '1.14357'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2019-02-05T00:15:00.000000000Z',
#    'ask': {'o': '1.14355', 'h': '1.14370', 'l': '1.14350', 'c': '1.14358'}},
#   {'complete': True,
#    'volume': 20,
#    'time': '2019-02-05T00:20:00.000000000Z',
#    'ask': {'o': '1.14356', 'h': '1.14370', 'l': '1.14355', 'c': '1.14366'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2019-02-05T00:25:00.000000000Z',
#    'ask': {'o': '1.14369', 'h': '1.14379', 'l': '1.14363', 'c': '1.14379'}},
#   {'complete': True,
#    'volume': 55,
#    'time': '2019-02-05T00:30:00.000000000Z',
#    'ask': {'o': '1.14376', 'h': '1.14399', 'l': '1.14367', 'c': '1.14393'}},
#   {'complete': True,
#    'volume': 35,
#    'time': '2019-02-05T00:35:00.000000000Z',
#    'ask': {'o': '1.14395', 'h': '1.14395', 'l': '1.14380', 'c': '1.14390'}},
#   {'complete': True,
#    'volume': 40,
#    'time': '2019-02-05T00:40:00.000000000Z',
#    'ask': {'o': '1.14392', 'h': '1.14397', 'l': '1.14377', 'c': '1.14379'}},
#   {'complete': True,
#    'volume': 13,
#    'time': '2019-02-05T00:45:00.000000000Z',
#    'ask': {'o': '1.14382', 'h': '1.14384', 'l': '1.14377', 'c': '1.14377'}},
#   {'complete': True,
#    'volume': 24,
#    'time': '2019-02-05T00:50:00.000000000Z',
#    'ask': {'o': '1.14380', 'h': '1.14391', 'l': '1.14372', 'c': '1.14372'}},
#   {'complete': True,
#    'volume': 19,
#    'time': '2019-02-05T00:55:00.000000000Z',
#    'ask': {'o': '1.14371', 'h': '1.14371', 'l': '1.14358', 'c': '1.14366'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2019-02-05T01:00:00.000000000Z',
#    'ask': {'o': '1.14368', 'h': '1.14374', 'l': '1.14361', 'c': '1.14363'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-02-05T01:05:00.000000000Z',
#    'ask': {'o': '1.14366', 'h': '1.14369', 'l': '1.14362', 'c': '1.14368'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-02-05T01:10:00.000000000Z',
#    'ask': {'o': '1.14371', 'h': '1.14380', 'l': '1.14371', 'c': '1.14379'}},
#   {'complete': True,
#    'volume': 9,
#    'time': '2019-02-05T01:15:00.000000000Z',
#    'ask': {'o': '1.14377', 'h': '1.14380', 'l': '1.14367', 'c': '1.14371'}},
#   {'complete': True,
#    'volume': 5,
#    'time': '2019-02-05T01:20:00.000000000Z',
#    'ask': {'o': '1.14374', 'h': '1.14374', 'l': '1.14368', 'c': '1.14373'}},
#   {'complete': True,
#    'volume': 4,
#    'time': '2019-02-05T01:25:00.000000000Z',
#    'ask': {'o': '1.14376', 'h': '1.14383', 'l': '1.14376', 'c': '1.14383'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-02-05T01:30:00.000000000Z',
#    'ask': {'o': '1.14380', 'h': '1.14397', 'l': '1.14380', 'c': '1.14393'}},
#   {'complete': True,
#    'volume': 7,
#    'time': '2019-02-05T01:35:00.000000000Z',
#    'ask': {'o': '1.14395', 'h': '1.14403', 'l': '1.14395', 'c': '1.14400'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2019-02-05T01:40:00.000000000Z',
#    'ask': {'o': '1.14397', 'h': '1.14399', 'l': '1.14394', 'c': '1.14395'}},
#   {'complete': True,
#    'volume': 20,
#    'time': '2019-02-05T01:45:00.000000000Z',
#    'ask': {'o': '1.14397', 'h': '1.14404', 'l': '1.14391', 'c': '1.14393'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2019-02-05T01:50:00.000000000Z',
#    'ask': {'o': '1.14391', 'h': '1.14396', 'l': '1.14389', 'c': '1.14394'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-02-05T01:55:00.000000000Z',
#    'ask': {'o': '1.14396', 'h': '1.14396', 'l': '1.14387', 'c': '1.14388'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2019-02-05T02:00:00.000000000Z',
#    'ask': {'o': '1.14387', 'h': '1.14391', 'l': '1.14382', 'c': '1.14385'}},
#   {'complete': True,
#    'volume': 6,
#    'time': '2019-02-05T02:05:00.000000000Z',
#    'ask': {'o': '1.14388', 'h': '1.14395', 'l': '1.14387', 'c': '1.14395'}},
#   {'complete': True,
#    'volume': 7,
#    'time': '2019-02-05T02:10:00.000000000Z',
#    'ask': {'o': '1.14392', 'h': '1.14396', 'l': '1.14387', 'c': '1.14396'}},
#   {'complete': True,
#    'volume': 16,
#    'time': '2019-02-05T02:15:00.000000000Z',
#    'ask': {'o': '1.14399', 'h': '1.14404', 'l': '1.14391', 'c': '1.14391'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-02-05T02:20:00.000000000Z',
#    'ask': {'o': '1.14393', 'h': '1.14401', 'l': '1.14391', 'c': '1.14400'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2019-02-05T02:25:00.000000000Z',
#    'ask': {'o': '1.14403', 'h': '1.14410', 'l': '1.14401', 'c': '1.14404'}},
#   {'complete': True,
#    'volume': 31,
#    'time': '2019-02-05T02:30:00.000000000Z',
#    'ask': {'o': '1.14407', 'h': '1.14412', 'l': '1.14390', 'c': '1.14393'}},
#   {'complete': True,
#    'volume': 29,
#    'time': '2019-02-05T02:35:00.000000000Z',
#    'ask': {'o': '1.14395', 'h': '1.14399', 'l': '1.14384', 'c': '1.14394'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-02-05T02:40:00.000000000Z',
#    'ask': {'o': '1.14391', 'h': '1.14393', 'l': '1.14384', 'c': '1.14384'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-02-05T02:45:00.000000000Z',
#    'ask': {'o': '1.14386', 'h': '1.14389', 'l': '1.14384', 'c': '1.14389'}},
#   {'complete': True,
#    'volume': 15,
#    'time': '2019-02-05T02:50:00.000000000Z',
#    'ask': {'o': '1.14391', 'h': '1.14400', 'l': '1.14389', 'c': '1.14395'}},
#   {'complete': True,
#    'volume': 12,
#    'time': '2019-02-05T02:55:00.000000000Z',
#    'ask': {'o': '1.14392', 'h': '1.14402', 'l': '1.14392', 'c': '1.14399'}},
#   {'complete': True,
#    'volume': 14,
#    'time': '2019-02-05T03:00:00.000000000Z',
#    'ask': {'o': '1.14397', 'h': '1.14399', 'l': '1.14389', 'c': '1.14389'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2019-02-05T03:05:00.000000000Z',
#    'ask': {'o': '1.14387', 'h': '1.14394', 'l': '1.14378', 'c': '1.14391'}},
#   {'complete': True,
#    'volume': 11,
#    'time': '2019-02-05T03:10:00.000000000Z',
#    'ask': {'o': '1.14388', 'h': '1.14388', 'l': '1.14373', 'c': '1.14373'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-02-05T03:15:00.000000000Z',
#    'ask': {'o': '1.14371', 'h': '1.14381', 'l': '1.14371', 'c': '1.14374'}},
#   {'complete': True,
#    'volume': 18,
#    'time': '2019-02-05T03:20:00.000000000Z',
#    'ask': {'o': '1.14371', 'h': '1.14373', 'l': '1.14363', 'c': '1.14373'}},
#   {'complete': True,
#    'volume': 10,
#    'time': '2019-02-05T03:25:00.000000000Z',
#    'ask': {'o': '1.14370', 'h': '1.14378', 'l': '1.14370', 'c': '1.14378'}},
#   {'complete': True,
#    'volume': 86,
#    'time': '2019-02-05T03:30:00.000000000Z',
#    'ask': {'o': '1.14376', 'h': '1.14389', 'l': '1.14358', 'c': '1.14360'}},
#   {'complete': True,
#    'volume': 45,
#    'time': '2019-02-05T03:35:00.000000000Z',
#    'ask': {'o': '1.14362', 'h': '1.14372', 'l': '1.14354', 'c': '1.14362'}},
#   {'complete': True,
#    'volume': 49,
#    'time': '2019-02-05T03:40:00.000000000Z',
#    'ask': {'o': '1.14366', 'h': '1.14373', 'l': '1.14353', 'c': '1.14366'}},
#   {'complete': True,
#    'volume': 26,
#    'time': '2019-02-05T03:45:00.000000000Z',
#    'ask': {'o': '1.14364', 'h': '1.14364', 'l': '1.14346', 'c': '1.14358'}},
#   {'complete': True,
#    'volume': 44,
#    'time': '2019-02-05T03:50:00.000000000Z',
#    'ask': {'o': '1.14355', 'h': '1.14355', 'l': '1.14329', 'c': '1.14343'}},
#   {'complete': True,
#    'volume': 25,
#    'time': '2019-02-05T03:55:00.000000000Z',
#    'ask': {'o': '1.14341', 'h': '1.14344', 'l': '1.14333', 'c': '1.14338'}},
#   {'complete': True,
#    'volume': 30,
#    'time': '2019-02-05T04:00:00.000000000Z',
#    'ask': {'o': '1.14341', 'h': '1.14352', 'l': '1.14333', 'c': '1.14348'}},
#   {'complete': True,
#    'volume': 37,
#    'time': '2019-02-05T04:05:00.000000000Z',
#    'ask': {'o': '1.14346', 'h': '1.14346', 'l': '1.14316', 'c': '1.14321'}},
#   ...]}

# %%
data = pd.DataFrame.from_dict(json_normalize(response['candles']), orient='columns')
data = data.rename(index = str, columns = 
                   {"ask.l" : "ask_l",
                   "ask.o" : "ask_o",
                   "ask.h" : "ask_h",
                   "ask.c" : "ask_c"})
data['pair'] = pair
data['unix'] = data['time'].apply(lambda x : mktime(dateutil.parser.parse(x).timetuple()))
data['DateTime'] = data['unix'].apply(lambda x : datetime.utcfromtimestamp(x).strftime('%Y-%m-%d-%H-%M'))
data['Yr'] = data['unix'].apply(lambda x : datetime.utcfromtimestamp(x).strftime('%Y'))
data['Mo'] = data['unix'].apply(lambda x : datetime.utcfromtimestamp(x).strftime('%m'))
data['Day'] = data['unix'].apply(lambda x : datetime.utcfromtimestamp(x).strftime('%d'))
data['Hour'] = data['unix'].apply(lambda x : datetime.utcfromtimestamp(x).strftime('%H'))
data['Minute'] = data['unix'].apply(lambda x : datetime.utcfromtimestamp(x).strftime('%M'))

data.head()
# Out:
#      ask_c    ask_h    ask_l    ask_o  complete  \
# 0  1.14226  1.14228  1.14202  1.14219      True
# 1  1.14196  1.14224  1.14193  1.14224      True
# 2  1.14175  1.14194  1.14160  1.14194      True
# 3  1.14181  1.14188  1.14163  1.14178      True
# 4  1.14141  1.14194  1.14140  1.14183      True
#
#                              time  volume     pair          unix  \
# 0  2019-01-30T16:40:00.000000000Z      54  EUR_USD  1.548895e+09
# 1  2019-01-30T16:45:00.000000000Z      70  EUR_USD  1.548896e+09
# 2  2019-01-30T16:50:00.000000000Z      85  EUR_USD  1.548896e+09
# 3  2019-01-30T16:55:00.000000000Z      77  EUR_USD  1.548896e+09
# 4  2019-01-30T17:00:00.000000000Z     110  EUR_USD  1.548896e+09
#
#            DateTime    Yr  Mo Day Hour Minute
# 0  2019-01-31-00-40  2019  01  31   00     40
# 1  2019-01-31-00-45  2019  01  31   00     45
# 2  2019-01-31-00-50  2019  01  31   00     50
# 3  2019-01-31-00-55  2019  01  31   00     55
# 4  2019-01-31-01-00  2019  01  31   01     00

# %%
table_name_Source = pair+"_"+gran+"_"+price+"_Source"

# %%
#Create Table Name

with engine.connect() as con:
    con.execute(f'drop table if exists {table_name_Source};')
    con.execute(f'''create table if not exists {table_name_Source} 
                (ask_c decimal(13,5), 
                ask_h decimal(13,5),
                ask_l decimal(13,5),
                ask_o decimal(13,5),
                complete boolean,
                time varchar(255),
                volume int,
                pair varchar(255),
                unix double,
                DateTime varchar(255),
                Yr double,
                Mo double,
                Day double,
                Hour double,
                Minute double,
                PRIMARY KEY (unix)
                )

;''')






#Create Primary Key
# Out:
# /Users/gregpoppe/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (1051, "Unknown table 'raw_data_db.eur_usd_m5_a_source'")
#   result = self._query(query)

# %%
data.to_sql(name=table_name_Source, con=engine, if_exists='append', index=False)
